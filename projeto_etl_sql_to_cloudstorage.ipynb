# %% [markdown]
# <a href="https://colab.research.google.com/github/nairtm/Analista_de_dados_Flora_SoulCode/blob/main/projetonair.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.1.0

# %%
import mysql.connector
import pandas as pd

# %%
host = '34.30.237.57' # endereço do banco externo que eu quero acessar
user = 'root'
password = ''
database = 'loja'

# %%
# !curl ipecho.net/plain
# Out:
# 34.125.201.163

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show tables;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#      Tables_in_loja
# 0         Categoria
# 1           Cliente
# 2        ItemPedido
# 3            Pedido
# 4           Produto
# 5  ProdutoCategoria

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Cliente;
'''
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
cliente = pd.DataFrame(result,columns=cursor.column_names)
display(cliente)
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_cliente         nome endereco
# 0            1      Douglas       SP
# 1            2      Daniela       SP
# 2            3        Ester       MG
# 3            4        Maria       BA
# 4            5      Douglas       PE
# 5            6     Raimundo       CE
# 6            7     Jucimara       GO
# 7            8      Marlene       AC
# 8            9      Douglas       MA
# 9           10      Daniela       PI
# 10          11        Pedro       PB
# 11          12      Joaquim       RS
# 12          13        Julio       TO
# 13          14        Carla       DF
# 14          15       Bianca       PA
# 15          16       Sandra       SP
# 16          17        Celso       SP
# 17          18      Silvana       BA
# 18          19  Prof Raquel       BA
# 19          20        Pedro       SP
# 20          21        Erick       BA
# 21          22       Denise       DF
# 22          23        Diana       SP
# 23          24       Dagmar       DF
# 24          25    Deiverson       SP

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'projeto-nair-440013'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'databasenairloja'
bucket = client.bucket(bucket_name)
cliente.to_csv('loja_cliente.csv',index=False) #mudar essa linha nas aspas e no inicio
from google.cloud import storage
destination_blob_name = 'tabelas/loja_cliente.csv' #mudar essa linha
source_file_name = 'loja_cliente.csv' #mudar essa linha
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Pedido;
'''
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
pedido = pd.DataFrame(result,columns=cursor.column_names)
display(pedido)
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_pedido  id_cliente descricao
# 0           1           1    Caneca
# 1           2           1     Garfo
# 2           3           2      Faca
# 3           4           5      Copo
# 4           5          19      Copo
# 5           6          19    Colher
# 6           7          15    Colher
# 7           8           8    Colher
# 8           9           2      Copo
# 9          10          19    Colher
# 10         11           6      Copo
# 11         12          11    Colher
# 12         13          10     Garfo
# 13         14           4     Garfo
# 14         15           3    Colher
# 15         16           3     Garfo
# 16         17           2      Copo
# 17         18          17     Garfo
# 18         19          14    Caneca
# 19         20          13    Caneca

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'projeto-nair-440013'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'databasenairloja'
bucket = client.bucket(bucket_name)
pedido.to_csv('loja_pedido.csv',index=False) #mudar essa linha nas aspas e no inicio
from google.cloud import storage
destination_blob_name = 'tabelas/loja_pedido.csv' #mudar essa linha
source_file_name = 'loja_pedido.csv' #mudar essa linha
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Produto;
'''
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
produto = pd.DataFrame(result,columns=cursor.column_names)
display(produto)
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_produto    nome  preco
# 0           1  Caneca  15.99
# 1           2   Garfo   5.99
# 2           3    Faca   7.99
# 3           4  Colher   3.99
# 4           5    Copo  10.99

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'projeto-nair-440013'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'databasenairloja'
bucket = client.bucket(bucket_name)
produto.to_csv('loja_produto.csv',index=False) #mudar essa linha nas aspas e no inicio
from google.cloud import storage
destination_blob_name = 'tabelas/loja_produto.csv' #mudar essa linha
source_file_name = 'loja_produto.csv' #mudar essa linha
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM ItemPedido;
'''
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
itempedido = pd.DataFrame(result,columns=cursor.column_names)
display(itempedido)
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_item  id_pedido  id_produto  quantidade
# 0         1          1           1           2
# 1         2          2           2           5
# 2         3          3           3           7
# 3         4          4           5          10
# 4         5          5           5          11
# 5         6          6           4          30
# 6         7          7           4          32
# 7         8          8           4          44
# 8         9          9           5          13
# 9        10         10           4          33
# 10       11         11           5          34
# 11       12         12           4          32
# 12       13         13           2          33
# 13       14         14           2          34
# 14       15         15           4          27
# 15       16         16           2          18
# 16       17         17           5          17
# 17       18         18           2          33
# 18       19         19           1          50
# 19       20         20           1          47

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'projeto-nair-440013'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'databasenairloja'
bucket = client.bucket(bucket_name)
itempedido.to_csv('loja_itempedido.csv',index=False) #mudar essa linha nas aspas e no inicio
from google.cloud import storage
destination_blob_name = 'tabelas/loja_itempedido.csv' #mudar essa linha
source_file_name = 'loja_itempedido.csv' #mudar essa linha
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Categoria;
'''
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
categoria = pd.DataFrame(result,columns=cursor.column_names)
display(categoria)
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_categoria   nome
# 0             1  Comer
# 1             2  Beber

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'projeto-nair-440013'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'databasenairloja'
bucket = client.bucket(bucket_name)
categoria.to_csv('loja_categoria.csv',index=False) #mudar essa linha nas aspas e no inicio
from google.cloud import storage
destination_blob_name = 'tabelas/loja_categoria.csv' #mudar essa linha
source_file_name = 'loja_categoria.csv' #mudar essa linha
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM ProdutoCategoria;
'''
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
produtocategoria = pd.DataFrame(result,columns=cursor.column_names)
display(produtocategoria)
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_produto  id_categoria
# 0           2             1
# 1           3             1
# 2           4             1
# 3           1             2
# 4           5             2

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'projeto-nair-440013'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'databasenairloja'
bucket = client.bucket(bucket_name)
produtocategoria.to_csv('loja_produtocategoria.csv',index=False) #mudar essa linha nas aspas e no inicio
from google.cloud import storage
destination_blob_name = 'tabelas/loja_produtocategoria.csv' #mudar essa linha
source_file_name = 'loja_produtocategoria.csv' #mudar essa linha
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].
